# %%
import torch 
import torch.nn as nn
import torchaudio
import librosa
import numpy as np
from matplotlib import pyplot as plt
from model import SingleExtractor

# %%
device = torch.device(0)

# %%
data, sample_rate = torchaudio.load('../Data/MTAT/the_marginal_prophets-bohemian_rap_cd-01-beatloaf-0-29.wav')

# %%
data.shape[1]/sample_rate
# Out:
# 29.124

# %%
data1, sample_rate1 = librosa.load('../Data/MTAT/the_marginal_prophets-bohemian_rap_cd-01-beatloaf-0-29.wav', sr=16000)

# %%
S = torchaudio.transforms.Spectrogram(n_fft=513, hop_length=513//4, power=1)
spe = S(data)
spe.shape
# Out:
# torch.Size([1, 257, 3641])

# %%
spe1 = librosa.core.stft(data1, n_fft=513)
spe1.shape
# Out:
# (257, 3641)

# %%
D = librosa.stft(data1, n_fft=513)
spe2, phase = librosa.magphase(D)
spe2.shape
# Out:
# (257, 3641)

# %%
print (spe.dtype)
print (spe1.dtype)
print (spe2.dtype)
# Out:
# torch.float32
# complex64
# float32

# %%
from librosa.display import specshow

# %%
spe0 = spe[0].numpy()
specshow(librosa.amplitude_to_db(abs(spe0)), x_axis='time', y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.show()

# %%
specshow(librosa.amplitude_to_db(spe2), x_axis='time', y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.show()

# %%
spe = np.load('../Data/spectrogram_pos/0_the_bots-now_is_the_time-12-the_secret_of_life-30-59_17.75.npy')

# %%
spee = np.load('../Data/spectrogram_pos/57_the_marginal_prophets-bohemian_rap_cd-07-spank_you-117-146_0.98.npy')

# %%
spe = torch.tensor(spe).unsqueeze(0).to(device)

# %%
ext = SingleExtractor(learn_bw='only_Q').to(device)

# %%
x = ext(spe)

# %%
spee = torch.tensor(spee).unsqueeze(0).to(device)

# %%
x
# Out:
# tensor([[7.2578e-01, 8.7109e-01, 5.4366e-02, 6.1611e-03, 1.9621e-02, 6.4397e-01,
#          9.6324e-01, 4.4858e-02, 3.1748e-02, 5.3778e-01, 3.4751e-01, 2.5787e-01,
#          7.2788e-01, 2.6817e-01, 3.3815e-01, 1.6395e-01, 1.4709e-01, 1.0336e-01,
#          8.0201e-01, 8.3110e-01, 7.8658e-01, 5.2864e-01, 7.8155e-01, 8.2931e-01,
#          3.5573e-01, 2.3074e-01, 3.1331e-01, 2.1720e-01, 6.2913e-03, 4.9849e-01,
#          5.3208e-02, 9.6060e-01, 8.6428e-01, 8.3473e-01, 8.2017e-01, 1.7824e-02,
#          7.8824e-01, 6.7881e-03, 4.5779e-01, 9.2597e-01, 9.6975e-01, 8.5445e-01,
#          5.2949e-01, 6.3632e-02, 5.7768e-02, 7.4357e-01, 7.7408e-02, 2.9310e-02,
#          8.0205e-01, 9.4341e-01, 4.3433e-02, 3.0264e-01, 8.3329e-01, 5.1952e-02,
#          5.4715e-02, 2.8158e-02, 2.9394e-01, 9.9971e-02, 2.8501e-01, 9.9129e-01,
#          1.2674e-01, 1.1259e-01, 4.0198e-01, 8.6646e-01, 6.3179e-01, 6.5180e-02,
#          8.2239e-04, 3.5136e-02, 2.7764e-01, 9.0896e-01, 5.8961e-01, 3.9973e-01,
#          9.7820e-01, 9.8484e-01, 4.4714e-01, 9.3989e-01, 9.4471e-01, 6.8552e-01,
#          3.1819e-01, 9.9808e-01, 6.8485e-01, 9.3785e-01, 2.7076e-02, 7.8498e-01,
#          8.9946e-01, 9.0613e-01, 4.5461e-02, 7.0697e-01, 9.5588e-01, 4.5396e-02,
#          7.1602e-01, 2.9206e-01, 6.9273e-02, 9.3950e-01, 9.9902e-01, 5.0562e-03,
#          6.2229e-01, 2.0913e-02, 4.2756e-01, 1.8120e-02, 7.4799e-03, 3.0092e-01,
#          1.0092e-01, 4.5361e-02, 2.9831e-01, 7.6014e-01, 8.6081e-01, 9.9607e-01,
#          1.2451e-02, 4.5643e-02, 7.9632e-01, 8.7229e-02, 6.0488e-02, 8.0415e-01,
#          6.9116e-01, 2.8018e-02, 9.7714e-01, 2.2118e-01, 4.9587e-01, 2.9374e-01,
#          1.4947e-02, 2.0860e-01, 2.1796e-01, 4.4946e-01, 9.9828e-01, 7.4319e-01,
#          1.8252e-01, 9.3780e-01, 7.7774e-01, 9.0771e-01, 1.8193e-01, 8.8199e-01,
#          3.2853e-01, 1.3230e-01, 3.3006e-01, 6.0891e-02, 9.7462e-01, 1.3473e-03,
#          8.3160e-01, 8.1431e-01, 9.9567e-01, 6.5917e-01, 8.3296e-01, 9.2090e-01,
#          6.7484e-01, 1.0965e-01, 3.7039e-01, 9.0646e-01, 5.7960e-01, 4.9279e-02,
#          5.9496e-01, 6.0362e-01, 7.9902e-02, 1.7368e-01, 9.0419e-01, 8.4773e-01,
#          9.5437e-01, 5.5005e-01, 9.8857e-01, 1.0651e-02, 9.8547e-01, 8.7496e-01,
#          4.7158e-01, 7.6044e-01, 9.9037e-01, 9.3963e-01, 1.9471e-01, 3.3886e-01,
#          4.4378e-02, 8.5860e-01, 1.3523e-01, 7.9866e-01, 9.6219e-01, 9.4371e-01,
#          2.7759e-02, 5.4753e-01, 5.9085e-01, 1.9033e-01, 8.6014e-01, 8.4251e-01,
#          9.7854e-01, 7.4347e-01, 9.9208e-01, 1.3306e-02, 4.1915e-01, 6.0866e-01,
#          3.6453e-01, 5.4985e-01, 8.9892e-01, 3.6496e-01, 3.3152e-01, 1.8762e-01,
#          5.9680e-02, 7.5083e-01, 9.2973e-01, 9.9723e-01, 8.5823e-01, 9.6220e-03,
#          8.1799e-01, 6.8591e-01, 9.9395e-01, 1.7842e-02, 9.9217e-02, 9.2038e-01,
#          3.4593e-01, 3.3434e-01, 7.1181e-01, 2.4308e-01, 9.8123e-01, 8.2552e-01,
#          4.3120e-01, 1.1454e-01, 1.0649e-02, 1.6179e-01, 6.8457e-01, 1.2108e-01,
#          9.9243e-01, 4.9037e-01, 9.9144e-01, 4.5287e-01, 4.1969e-01, 2.0782e-01,
#          2.8966e-01, 6.4411e-02, 3.3504e-01, 1.5016e-01, 9.5061e-01, 3.7892e-01,
#          9.8414e-01, 2.0114e-02, 1.0276e-02, 8.9145e-01, 5.1496e-02, 6.6000e-01,
#          8.7244e-02, 2.4707e-01, 8.3065e-02, 1.9062e-01, 1.0692e-01, 8.4151e-01,
#          9.1925e-01, 9.9292e-02, 8.4741e-03, 8.5683e-01, 7.3780e-01, 7.3258e-01,
#          3.4147e-03, 9.1841e-01, 6.8020e-01, 4.9571e-01, 9.9721e-01, 2.1623e-02,
#          9.8098e-02, 1.3637e-01, 1.0202e-01, 7.4623e-01]], device='cuda:0',
#        grad_fn=<SigmoidBackward>)

# %%
xx = ext(spee)

# %%
xx.device
# Out:
# device(type='cuda', index=0)
